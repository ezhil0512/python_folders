# %%
print("hello world")
# Out:
# hello world

# %%
'''
s=input()
print("printed statement "+s)
'''
print("hi")
# Out:
# hi

# %%
import sys
print(sys.version)
# Out:
# 3.12.4 | packaged by Anaconda, Inc. | (main, Jun 18 2024, 15:03:56) [MSC v.1929 64 bit (AMD64)]

# %%
age=int(input("enter the age"))
print(age)
print(id(age))
print(age,id(age),age,id(age))
# Out:
# enter the age 88
# 88
# 140719286142104
# 88 140719286142104 88 140719286142104

# %%
name=input("enter your name")
age=int(input("enter your age"))
height=float(input("enter the height"))
status=bool(input("enter the status"))
print(name,age,height,status)
# Out:
# enter your name nn
# enter your age 99
# enter the height 77.9
# enter the status True
# nn 99 77.9 True

# %%
import random
random.randint(1,90)
# Out:
# 5

# %%
print(0.1 + 0.2)
from decimal import Decimal
print(Decimal("0.1") + Decimal("0.2"))
# Out:
# 0.30000000000000004
# 0.3

# %%
age=int(input())
x="adult" if age>=20 else "child"
print(x)
# Out:
#  1
# child

# %%
def func():
    a=int(input("enter the number"))
    return a
func()
# Out:
# enter the number 2
# 2

# %%
def function(a,b):
    return a+b
function(10,2)
# Out:
# 12

# %%
def kfun(a,b):
    return a-b
kfun(b=10,a=5)
# Out:
# -5

# %%
l=[]
type(l)
id(l)
# Out:
# 2006380161088

# %%
l=[10,3,4,5]
print(l)
n=[1,'anand',11,1.2,True,88]
print(n)
print(n[0])
print(n[0],n[2])
# Out:
# [10, 3, 4, 5]
# [1, 'anand', 11, 1.2, True, 88]
# 1
# 1 11

# %%
n[1]='ravi'
print(n)
print(n[-5])
n[-1]
n[-2]
# Out:
# [1, 'ravi', 11, 1.2, True, 88]
# ravi
# True

# %%
#slide
#  0 1 2 3 4 5 6
l=[2,3,4,5,6,7,8]
print(l[1:4])
print(l[1:6])
print(l[1:-1])
print(l[:3])
print(l[0:])
print(l[4:4])
print(l[-1:4])
print(l[4:-1])
print(l[-6:-4])
print(l[-6:5])
print(l[0:9])
# Out:
# [3, 4, 5]
# [3, 4, 5, 6, 7]
# [3, 4, 5, 6, 7]
# [2, 3, 4]
# [2, 3, 4, 5, 6, 7, 8]
# []
# []
# [6, 7]
# [3, 4]
# [3, 4, 5, 6]
# [2, 3, 4, 5, 6, 7, 8]

# %%
l[-1:]
# Out:
# [8]

# %%
#silde with stride
l[::-1]
l[6:0:-1]
l[6:0:1]
# Out:
# []
