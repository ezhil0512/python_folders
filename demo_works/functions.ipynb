# %%
def sum(*numbers):
    res=0
    for i in numbers:
        res+=i
    return res

sum(1,2,3,4,5)
# Out:
# 15

# %%
def diff(a,b):
    return abs(a-b)
diff(10,5)
# Out:
# 5

# %%
def sub(*numbers):
    res
# Out:
# 5

# %%
def product(*numbers):
    res=1
    for i in numbers:
        res*=i
    return res
product(1,2,3,4,5)

product(1,2,3)
# Out:
# 6

# %%
def mypow(a,b):
    res=1
    for i in range(0,b):
        res*=a
    print(res)
mypow(2,3)
mypow(3,4)
# Out:
# 8
# 81

# %%
def recvolume(l=1,b=1,h=1):
