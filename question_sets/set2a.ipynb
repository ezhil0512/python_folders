# %%
temp=float(input("enter the temperature in celcius"))
if temp<=19:
    print("cool")
elif temp>19 and temp<40:
    print("warm")
else:
    print("hot")
# Out:
# enter the temperature in celcius 44
# hot

# %%
a=int(input("enter the number"))
if (a//2)*2==a:
    print("even")
else:
    print("odd")
# Out:
# enter the number 5
# odd

# %%
num=int(input("enter the number of wheels"))
if num==2:
    print("bike")
elif num==4:
    print("car")
elif num>4:
    print("truck")
# Out:
# enter the number of wheels 8
# truck

# %%
s=input("enter the letter")
if len(s)==1:
 if s in "ABCDEFGHIJKLMNOPQRSTUVWXYZ":
    print("uppercase")
 else:
    print("lowercase")
# Out:
# enter the letter AB

# %%
num=int(input("enter the current munth in number"))
if num==1:
    print("february")
elif num==2:
    print("march")
elif num==3:
    print("april")
elif num==4:
    print("may")
elif num==5:
    print("june")
elif num==6:
    print("july")
elif num==7:
    print("august")
elif num==8:
    print("september")
elif num==9:
    print("october")
elif num==10:
    print("november")
elif num==11:
    print("december")
elif num==12:
    print("january")
# Out:
# enter the current munth in number 5
# june

# %%
s=input("enter the charactor")
if len(s)==1:
    if s=='R':
        print("RED")
    elif s=='Y':
        print("YELLOW") 
    elif s=='G':
        print("GREEN")
# Out:
# enter the charactor R
# RED

# %%
day=input("enter the day")
if day in ("monday","tuesday","wednesday","thursday","friday","saturday"):
    print("working day")
else:
    print("holiday")
# Out:
# enter the day ","
# holiday

# %%
ch=input("enter the charactor")
if len(ch)==1:
    if ch in "1234567890":
        print("digit")
    elif ch in "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ":
        print("letter")
    else:
        print("symbol")
# Out:
# enter the charactor %
# symbol

# %%
km=float(input("enter the distance in kilo meter"))
if km<=1:
    print("walk")
elif km>1 and km<200:
    print("car")
else:
    print("plane")
# Out:
# enter the distance in kilo meter 2
# car
