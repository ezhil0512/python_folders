# %%
num=int(input("enter the number"))
sum=0
while(num!=0):
    r=num%10
    sum+=r
    num=num//10
print(sum)
# Out:
# enter the number 65
# 11

# %%
num=int(input("enter the number"))
count=0
while(num!=0):
    r=num%10
    count+=1
    num=num//10
if count%2==0:
    print("even length")
else:
    print("odd length")
# Out:
# enter the number 6666
# even length

# %%
num=int(input("enter the number"))
count=0
while(num>0):
    r=num%10
    num=num//10
    count+=1
print(count)
# Out:
# enter the number 55555555
# 8

# %%
num=int(input("enter the number"))
sum=0
while num!=0:
    r=num%10
    sum+=r
    num=num//100
print("sum "+str(sum))
# Out:
# enter the number 123456
# sum 12

# %%
num=int(input("enter the number"))
odd=0
even=0
while num!=0:
    r=num%10
    if r%2==0:
        even+=1
    else:
        odd+=1
    num=num//10
print("odd numbers "+str(odd)+"\neven number "+str(even))
# Out:
# enter the number 4444444
# odd numbers 0
# even number 7

# %%
num=int(input("enter the number"))
odd=0
even=0
while num!=0:
    r=num%10
    if r%2==0:
        even+=r
    else:
        odd+=r
    num=num//10
print("odd sum "+str(odd)+"\neven sum "+str(even))
# Out:
# enter the number 4443333
# odd sum 12
# even sum 12

# %%
n=int(input("enter the number"))
r=n%10
print("last digit "+str(r))
# Out:
# enter the number 111345
# last digit 5

# %%
num=int(input("enter the number"))
f=0
while num!=0:
    r=num%10
    f=r
    num=num//10
print("first digit "+str(f))
# Out:
# enter the number 12345
# first digit 1

# %%
num=int(input("enter the number"))
temp=0
while num!=0:
    r=num%10
    if r>temp:
        temp=r
    num=num//10
print("maximum "+str(temp))
# Out:
# enter the number 5972
# maximum 9

# %%
num=int(input("enter the number"))
pos=1
c=0
ans=0
while(num!=0):
    r=num%10
    if(r>c):
        c=r
        ans=pos
    num=num//10
    pos=pos*10
print(ans)
# Out:
# enter the number 1000
# 1000

# %%
num=int(input("enter the number"))
temp=9
while(num!=0):
    r=num%10
    if r<temp:
        temp=r
    num=num//10
print("minimum "+str(temp))
# Out:
# enter the number 3241
# minimum 1

# %%
num=int(input("enter the number"))
min=9
ans=0
pos=1
while(num!=0):
    r=num%10
    if r<min:
        min=r
        ans=pos
    num=num//10
    pos=pos*10
print("position "+str(ans))
# Out:
# enter the number 54828
# position 10

# %%
num=int(input("enter the number"))
temp=0
while(num!=0):
    r=num%10
    temp=temp*10+r
    num=num//10
print("reverse "+str(temp))
# Out:
# enter the number 1234
# reverse 4321

# %%
num=int(input("enter the number"))
while(num>9):
    ans=0
    while num!=0:
        r=num%10
        ans=ans+r
        num=num//10
    num=ans
print(ans)
# Out:
# enter the number 3456
# 9

# %%
num=int(input("enter the number"))
div=int(input("enter the diviser"))
ans=True
while(num!=0):
    r=num%10
    if(r%div!=0):
        ans=False
        break
    num=num//10
print(ans)
# Out:
# enter the number 368
# enter the diviser 3
# False

# %%
num=int(input("enter the number"))
div=int(input("enter the diviser"))
ans=0
while(num!=0):
    r=num%10
    if r%div==0:
        ans+=1
    num=num//10
print("count "+str(ans))
# Out:
# enter the number 483
# enter the diviser 4
# count 2

# %%
num=int(input("enter the number"))
org=num
rev=0
while(num!=0):
    r=num%10
    rev=rev*10+r
    num=num//10
if org==rev:
    print("polindrom")
else:
    print("not a polindrom")
# Out:
# enter the number 123456123456
# not a polindrom

# %%
num=int(input("enter the number"))
ans=0
while num!=0:
    temp=0
    max=0
    number=num
    while number!=0:
        r=number%10
        if r>max:
            max=r
        ans
        number=number//10
# Out:
# enter the number 3618

# %%
# Out:
# enter the number 1908
# 8899
