# %% [markdown]
# print("hello world")

# %%
a=10;
b=10;
print(id(a),id(b))
# Out:
# 140733790960344 140733790960344

# %%
#print('hello world')

# %%
a=10
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>

# %%
b=10.5;
print(b);
print(type(b));
# Out:
# 10.5
# <class 'float'>

# %%
c='3';
print(c)
print(type(c));
# Out:
# 3
# <class 'str'>

# %%
d=True
print(d)
print(type(d))
# Out:
# True
# <class 'bool'>

# %%
print(type(d))
print(type(a))
print(a,b,c)
print(a+int(b)+int(c))
# Out:
# <class 'bool'>
# <class 'int'>
# 10 10.5 3
# 23

# %%
x=20
print(type(x))
x1=float(x)
# Out:
# <class 'int'>
