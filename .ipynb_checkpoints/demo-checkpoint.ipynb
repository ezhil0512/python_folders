# %%
print("hello world")
# Out:
# hello world

# %%
'''
s=input()
print("printed statement "+s)
'''
print("hi")
# Out:
# hi

# %%
import sys
print(sys.version)
# Out:
# 3.12.4 | packaged by Anaconda, Inc. | (main, Jun 18 2024, 15:03:56) [MSC v.1929 64 bit (AMD64)]

# %%
age=int(input("enter the age"))
print(age)
print(id(age))
print(age,id(age),age,id(age))
# Out:
#   Cell In[17], line 1
#     1age=int(input("enter the age"))
#     ^
# SyntaxError: invalid decimal literal
