# %%
number1=int(input("enter the number"))
if number1>0:
    print("pasitive")
elif number1<0:
    print("negative")
else:
    print("number is 0")
# Out:
# enter the number 2
# pasitive

# %%
num1=int(input("enter the first number"))
num2=int(input("enter the second number"))
if num1==num2:
    print("both are equal numbers")
else:
    print(" both are not equal")
# Out:
# enter the first number 2
# enter the second number 3
#  both are not equal

# %%
fnum1=float(input("enter the first float number"))
fnum2=float(input("enter the second float number"))
if fnum1==fnum2:
    print("both are same")
else:
    print("both are different")
# Out:
# enter the first float number 2.3
# enter the second float number 4.5
# both are different

# %%
number=int(input("enter the number"))
number="even" if(number%2==0) else "odd"
print(number)
# Out:
# enter the number 4
# even

# %%
year=int(input("enter the year"))
if year%4==0 and year%100!=0 or year%400==0 and year%100!=0:
    print('leap year')
else:
    print('not a leap year')
# Out:
# enter the year 1900
# not a leap year

# %%
age=int(input("enter your age"))
if age>=18 and age<110:
    print("eligible for vote")
elif age<18 and age>0:
    print("not eligible for vote")
else:
    print("invalid age")
# Out:
# enter your age 2
# not eligible for vote

# %%
height=float(input("enter your height"))
if height>=150:
    print("tall")
elif height>=120 and height<150:
    print("medium")
else:
    print("short")
# Out:
# enter your height 112.8
# short

# %%
num1=int(input("enter the first number"))
num2=int(input("enter the second number"))
num3=int(input("enter the third number"))
temp=num1
if num2>temp:
    temp=num2
if num3>temp:
    temp=num3
print(temp)
# Out:
# enter the first number 22
# enter the second number 33
# enter the third number 55
# 55

# %%
num1=int(input("enter the first number"))
num2=int(input("enter the second number"))
num3=int(input("enter the third number"))
temp=num1
if num2<temp:
    temp=num2
if num3<temp:
    temp=num3
print(temp)
# Out:
# enter the first number 11
# enter the second number 22
# enter the third number 33
# 11

# %%
num1=int(input("enter the number"))
num2=int(input("enter the second number"))
num3=int(input("enter the third number"))
num4=int(input("enter the fourth number"))
temp=num1
if num2>temp:
    temp=num2
if num3>temp:
    temp=num3
if num4>temp:
    temp=num4
print(temp)
# Out:
# enter the number 1111
# enter the second number 2
# enter the third number 3
# enter the fourth number 4
# 1111

# %%
import math
num1=int(input("enter the first number"))
num2=int(input("enter the second number"))
num3=int(input("enter the third number"))
sub1=abs(num1-num2)
sub2=abs(num2-num3)
sub3=abs(num3-num1)
mini=sub1
if mini>sub2:
    mini=sub2
if mini>sub3:
    mini=sub3
if mini==sub1:
    print('number 1 and numer 2')
if mini==sub2:
    print('number 2 and number 3')
if mini==sub3:
    print('number 1 and number 3')
# Out:
# enter the first number 10
# enter the second number 20
# enter the third number 30
# number 1 and numer 2
# number 2 and number 3

# %%
import math
num1=int(input("enter first number"))
num2=int(input("enter second number"))
num3=int(input("enter third number"))
sub1=abs(num1-num2)
sub2=abs(num2-num3)
sub3=abs(num3-num1)
maxi=sub1
if sub2>maxi:
    maxi=sub2
if sub3>maxi:
    maxi=sub3
if maxi==sub1:
    print('number 1 and number 2')
if maxi==sub2:
    print('number 2 and number 3')
if maxi==sub3:
    print('number 1 and number 3')
# Out:
# enter first number 10
# enter second number 10
# enter third number 30
# number 2 and number 3
# number 1 and number 3

# %%
num1=int(input('enter the first number'))
num2=int(input('enter the second number'))
num3=int(input('enter the third number'))
a=0
b=0
c=0
if num1>num2 and num1>num3:
    a=num1
if num2>num1 and num2>num3:
    a=num2
if num3>num2 and num3>num1:
    a=num3
if num1<num2 and num1<num3:
    c=num1
if num2<num1 and num2<num3:
    c=num2
if num3<num2 and num3<num1:
    c=num3
b=(num1+num2+num3)-(a+c)
print(a)
print(b)
print(c)
# Out:
# enter the first number 22
# enter the second number 66
# enter the third number 77
# 77
# 66
# 22

# %%
num1=int(input("enter the first angle"))
num2=int(input("enter the second angle"))
num3=int(input("enter the third angle"))
ans=num1+num2+num3
if ans==180:
    print('can make triangle')
else:
    print('can not make a triangle')
# Out:
# enter the first angle 40
# enter the second angle 40
# enter the third angle 40
# can not make a triangle

# %%
point1=int(input('enter the first point'))
point2=int(input('enter the second point'))
if point1==0 and point2==0:
    print("points lies in origin")
elif point1>0 and point2>0:
    print("points lies in first quardent")
elif point1<0 and point2>0:
    print("point lies in second quadrent")
elif point1<0 and point2<0:
    print("point lies in third qadrent")
elif point1>0 and point2<0:
    print("points lies in fourth quadrent")
elif point1==0:
    print("point lies on y axis")
else:
    print("points lies on x axis")
# Out:
# enter the first point 0
# enter the second point 0
# points lies in origin

# %%
l=input("enter the letter")
if l in "aeiou":
    print('given letter is vowel')
else:
    print('given letter us consonant')
# Out:
# enter the letter b
# given letter us consonant

# %%
num=int(input("enter the number of side"))
if num==3:
    print("triangle")
if num==4:
    print("square or rectangle")
if num==5:
    print("pentagon")
if num==6:
    print("hexagon")
if num==7:
    print("heptagon")
if num==8:
    print("octagon")
# Out:
# enter the number of side 5
# pentagon

# %%
month=input("enter the month")
if month=="january" or month=="march" or month=="may" or month=="july" or month=="august" or month=="october" or month=="december":
   print("31 days in the month")
elif month=="february":
   print("28 days in the month")
else:
   print("30 days in the month")
# Out:
# enter the month february
# 28 days in the month

# %%
date=int(input("enter the date"))
if date>0 and date<32:
    ans=date%7
    if ans==1:
        print("sunday")
    elif ans==2:
        print("monday")
    elif ans==3:
        print("tuesday")
    elif ans==4:
        print("wednesday")
    elif ans==5:
        print("thursday")
    elif ans==6:
        print("friday")
    else:
        print("saturday")
# Out:
# enter the date 13
# friday

# %%
n1=int(input("enter the first side"))
n2=int(input("enter the second side"))61
n3=int(input("enter the third side"))
if n1==n2 and n2==n3:
    print("equilateral")
elif n1==n2 or n2==n3 or n1==n3:
    print("scalene")
else:
    print("isoscalene")
# Out:
# enter the first side 61
# enter the second side 61
# enter the third side 16
# scalene

# %%
mark=int(input("enter the mark"))
if mark>=90:
    print("A")
elif mark>=80:
    print("B")
elif mark>=60:
    print("C")
elif mark>=50:
    print("D")
elif mark<50:
    print("F")
# Out:
# enter the mark 66
# C

# %%
row=int(input("enter the row"))
col=input("enter the column").lower
ans=(int)col-(int)'a'-1
if (row+ans)%2==0:
    print("black")
else:
    print("white")
# Out:
#   Cell In[4], line 3
#     ans=(int)col-(int)'a'-1
#              ^
# SyntaxError: invalid syntax

# %%
bp=int(input("enter the buying price"))
sp=int(input("enter the selling price"))
tot=sp-bp
if tot>0:
    print("profit")
elif tot==0:
    print("balanced")
else:
    print("loss")
