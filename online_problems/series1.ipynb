# %%
num=int(input())
if num%2==0 and num!=2:
    print("Yes")
else:
    print("No")
# Out:
#  2
# No

# %%
num1=int(input())
num2=int(input())
mul=num1*num2
if mul%2==0:
    print("Even")
else:
    print("odd")
# Out:
#  2
#  5
# Even

# %%
que=input()
if 'ba' in que:
    print("no")
else:
    print("yes")
# Out:
#  abab
# no
